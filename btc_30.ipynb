# %% [markdown]
# ### Import thư viện

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from datetime import datetime
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam, SGD

# %%
df = pd.read_csv('BTC-USD.csv')
df = df.sort_values('Date').reset_index(drop=True)

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %%
df.shape
# Out:
# (2817, 7)

# %% [markdown]
# ### Vẽ biểu đồ giá theo giá đóng của

# %%
#giá đóng cửa
df['Close'] = df['Close'].astype(float)

plt.figure(figsize=(20,7))
plt.plot(df['Date'].values, df['Close'].values, label = 'Bitcoin Stock Price', color = 'red')
plt.xticks(np.arange(100,df.shape[0],200))
plt.xlabel('Date')
plt.ylabel('Close ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
num_shape = 2000
train = df.iloc[:num_shape, 1:2].values
test = df.iloc[num_shape:, 1:2].values

# %%
sc = MinMaxScaler(feature_range = (0, 1))
train_scaled = sc.fit_transform(train)

# %%
X_train = []

#Price on next day
y_train = []

window = 30

for i in range(window, num_shape):
    X_train_ = np.reshape(train_scaled[i-window:i, 0], (window, 1))
    X_train.append(X_train_)
    y_train.append(train_scaled[i, 0])
X_train = np.stack(X_train)
y_train = np.stack(y_train)

# %% [markdown]
# ### Recurrent Neural Network

# %% [markdown]
# #### Training of the basic LSTM model

# %%
# Initializing the Recurrent Neural Network
model = Sequential()
#Adding the first LSTM layer with a sigmoid activation function and some Dropout regularization
#Units - dimensionality of the output space

model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50))
model.add(Dropout(0.2))

# Adding the output layer
model.add(Dense(units = 1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 50)            10400
#
#  dropout (Dropout)           (None, 30, 50)            0
#
#  lstm_1 (LSTM)               (None, 30, 50)            20200
#
#  dropout_1 (Dropout)         (None, 30, 50)            0
#
#  lstm_2 (LSTM)               (None, 30, 50)            20200
#
#  dropout_2 (Dropout)         (None, 30, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(X_train, y_train, epochs = 100, batch_size = 128);
# Out:
# Epoch 1/100
# 16/16 [==============================] - 6s 57ms/step - loss: 0.0207
# Epoch 2/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0052
# Epoch 3/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0037
# Epoch 4/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0032
# Epoch 5/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0029
# Epoch 6/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0031
# Epoch 7/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0029
# Epoch 8/100
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0026
# Epoch 9/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0025
# Epoch 10/100
# 16/16 [==============================] - 1s 64ms/step - loss: 0.0026
# Epoch 11/100
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0023
# Epoch 12/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0025
# Epoch 13/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.0023
# Epoch 14/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0022
# Epoch 15/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0021
# Epoch 16/100
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0020
# Epoch 17/100
# 16/16 [==============================] - 1s 64ms/step - loss: 0.0019
# Epoch 18/100
# 16/16 [==============================] - 1s 66ms/step - loss: 0.0020
# Epoch 19/100
# 16/16 [==============================] - 1s 64ms/step - loss: 0.0023
# Epoch 20/100
# 16/16 [==============================] - 1s 64ms/step - loss: 0.0020
# Epoch 21/100
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0018
# Epoch 22/100
# 16/16 [==============================] - 1s 66ms/step - loss: 0.0017
# Epoch 23/100
# 16/16 [==============================] - 1s 74ms/step - loss: 0.0017
# Epoch 24/100
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0020
# Epoch 25/100
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0018
# Epoch 26/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0017
# Epoch 27/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0015
# Epoch 28/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0016
# Epoch 29/100
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0015
# Epoch 30/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0015
# Epoch 31/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0019
# Epoch 32/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0017
# Epoch 33/100
# 16/16 [==============================] - 1s 64ms/step - loss: 0.0015
# Epoch 34/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0015
# Epoch 35/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0016
# Epoch 36/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0015
# Epoch 37/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0014
# Epoch 38/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0015
# Epoch 39/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0015
# Epoch 40/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0014
# Epoch 41/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0013
# Epoch 42/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0014
# Epoch 43/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0014
# Epoch 44/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0014
# Epoch 45/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0013
# Epoch 46/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0013
# Epoch 47/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0012
# Epoch 48/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0013
# Epoch 49/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0015
# Epoch 50/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0013
# Epoch 51/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0013
# Epoch 52/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0013
# Epoch 53/100
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0014
# Epoch 54/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0012
# Epoch 55/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0011
# Epoch 56/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0013
# Epoch 57/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0012
# Epoch 58/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0013
# Epoch 59/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0012
# Epoch 60/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0011
# Epoch 61/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0013
# Epoch 62/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0013
# Epoch 63/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0011
# Epoch 64/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0011
# Epoch 65/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0011
# Epoch 66/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0013
# Epoch 67/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0011
# Epoch 68/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0012
# Epoch 69/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0012
# Epoch 70/100
# 16/16 [==============================] - 1s 65ms/step - loss: 0.0011
# Epoch 71/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0011
# Epoch 72/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0012
# Epoch 73/100
# 16/16 [==============================] - 1s 62ms/step - loss: 0.0011
# Epoch 74/100
# 16/16 [==============================] - 1s 66ms/step - loss: 0.0010
# Epoch 75/100
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0011
# Epoch 76/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0011
# Epoch 77/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0010
# Epoch 78/100
# 16/16 [==============================] - 1s 63ms/step - loss: 0.0010
# Epoch 79/100
# 16/16 [==============================] - 1s 62ms/step - loss: 9.9510e-04
# Epoch 80/100
# 16/16 [==============================] - 1s 62ms/step - loss: 9.9715e-04
# Epoch 81/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0010
# Epoch 82/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0011
# Epoch 83/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0011
# Epoch 84/100
# 16/16 [==============================] - 1s 71ms/step - loss: 0.0011
# Epoch 85/100
# 16/16 [==============================] - 1s 62ms/step - loss: 9.9634e-04
# Epoch 86/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0011
# Epoch 87/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0011
# Epoch 88/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0010
# Epoch 89/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0010
# Epoch 90/100
# 16/16 [==============================] - 1s 61ms/step - loss: 9.9553e-04
# Epoch 91/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0011
# Epoch 92/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0010
# Epoch 93/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0010
# Epoch 94/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0011
# Epoch 95/100
# 16/16 [==============================] - 1s 61ms/step - loss: 9.4480e-04
# Epoch 96/100
# 16/16 [==============================] - 1s 62ms/step - loss: 8.8715e-04
# Epoch 97/100
# 16/16 [==============================] - 1s 61ms/step - loss: 8.2580e-04
# Epoch 98/100
# 16/16 [==============================] - 1s 61ms/step - loss: 8.0584e-04
# Epoch 99/100
# 16/16 [==============================] - 1s 62ms/step - loss: 8.9191e-04
# Epoch 100/100
# 16/16 [==============================] - 1s 62ms/step - loss: 9.2300e-04

# %% [markdown]
# #### Prediction

# %%
df_volume = np.vstack((train, test))

inputs = df_volume[df_volume.shape[0] - test.shape[0] - window:]
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

num_2 = df_volume.shape[0] - num_shape + window

X_test = []

for i in range(window, num_2):
    X_test_ = np.reshape(inputs[i-window:i, 0], (window, 1))
    X_test.append(X_test_)
    
X_test = np.stack(X_test)

# %%
predict = model.predict(X_test)
predict = sc.inverse_transform(predict)
# Out:
# 26/26 [==============================] - 1s 9ms/step

# %%
diff = predict - test

print("MSE:", np.mean(diff**2))
print("MAE:", np.mean(abs(diff)))
print("RMSE:", np.sqrt(np.mean(diff**2)))
# Out:
# MSE: 69784629.75174989
# MAE: 6294.351284081815
# RMSE: 8353.719515985073

# %%
plt.figure(figsize=(20,7))
plt.plot(df['Date'].values[1700:], df_volume[1700:], color = 'red', label = 'Real Bitcoin Price')
plt.plot(df['Date'][-predict.shape[0]:].values, predict, color = 'blue', label = 'Predicted Bitcoin Price')
plt.xticks(np.arange(100,df[1800:].shape[0],20))
plt.title('Bitcoin Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.show()

# %%
pred_ = predict[-1].copy()
prediction_full = []
window = 30
df_copy = df.iloc[:, 1:2][1:].values

for j in range(7):
    df_ = np.vstack((df_copy, pred_))
    train_ = df_[:num_shape]
    test_ = df_[num_shape:]
    
    df_volume_ = np.vstack((train_, test_))

    inputs_ = df_volume_[df_volume_.shape[0] - test_.shape[0] - window:]
    inputs_ = inputs_.reshape(-1,1)
    inputs_ = sc.transform(inputs_)

    X_test_2 = []

    for k in range(window, num_2):
        X_test_3 = np.reshape(inputs_[k-window:k, 0], (window, 1))
        X_test_2.append(X_test_3)

    X_test_ = np.stack(X_test_2)
    predict_ = model.predict(X_test_)
    pred_ = sc.inverse_transform(predict_)
    prediction_full.append(pred_[-1][0])
    df_copy = df_[j:]
# Out:
# 26/26 [==============================] - 0s 9ms/step
# 26/26 [==============================] - 0s 8ms/step
# 26/26 [==============================] - 0s 8ms/step
# 26/26 [==============================] - 0s 8ms/step
# 26/26 [==============================] - 0s 9ms/step
# 26/26 [==============================] - 0s 9ms/step
# 26/26 [==============================] - 0s 9ms/step

# %%
prediction_full_new = np.vstack((predict, np.array(prediction_full).reshape(-1,1)))

# %%
df_date = df[['Date']]

for h in range(7):
    df_date_add = pd.to_datetime(df_date['Date'].iloc[-1]) + pd.DateOffset(days=1)
    df_date_add = pd.DataFrame([df_date_add.strftime("%Y-%m-%d")], columns=['Date'])
    df_date = df_date.append(df_date_add)
df_date = df_date.reset_index(drop=True)

# %%
plt.figure(figsize=(20,7))
plt.plot(df['Date'].values[1700:], df_volume[1700:], color = 'red', label = 'Real Bitcoin Price')
plt.plot(df_date['Date'][-prediction_full_new.shape[0]:].values, prediction_full_new, color = 'blue', label = 'Predicted Bitcoin Price')
plt.xticks(np.arange(100,df[1700:].shape[0],200))
plt.title('Bitcoin Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.show()

# %% [markdown]
# ### GRU

# %%
# The GRU architecture
modelGRU = Sequential()

modelGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
modelGRU.add(Dropout(0.2))

modelGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
modelGRU.add(Dropout(0.2))

modelGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
modelGRU.add(Dropout(0.2))

modelGRU.add(GRU(units=50))
modelGRU.add(Dropout(0.2))

modelGRU.add(Dense(units=1))
modelGRU.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 30, 50)            7950
#
#  dropout_4 (Dropout)         (None, 30, 50)            0
#
#  gru_1 (GRU)                 (None, 30, 50)            15300
#
#  dropout_5 (Dropout)         (None, 30, 50)            0
#
#  gru_2 (GRU)                 (None, 30, 50)            15300
#
#  dropout_6 (Dropout)         (None, 30, 50)            0
#
#  gru_3 (GRU)                 (None, 50)                15300
#
#  dropout_7 (Dropout)         (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 53,901
# Trainable params: 53,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelGRU.compile(optimizer='adam', loss='mean_squared_error')
modelGRU.fit(X_train, y_train, epochs=100, batch_size=128)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 6s 51ms/step - loss: 0.0186
# Epoch 2/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0035
# Epoch 3/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0026
# Epoch 4/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.0022
# Epoch 5/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0019
# Epoch 6/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0019
# Epoch 7/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0018
# Epoch 8/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0018
# Epoch 9/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0017
# Epoch 10/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0016
# Epoch 11/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0016
# Epoch 12/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0016
# Epoch 13/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 14/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 15/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 16/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0015
# Epoch 17/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 18/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0015
# Epoch 19/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0016
# Epoch 20/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0014
# Epoch 21/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0013
# Epoch 22/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0013
# Epoch 23/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0013
# Epoch 24/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0012
# Epoch 25/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 26/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0013
# Epoch 27/100
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0012
# Epoch 28/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0011
# Epoch 29/100
# 16/16 [==============================] - 1s 56ms/step - loss: 0.0012
# Epoch 30/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0015
# Epoch 31/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0013
# Epoch 32/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0012
# Epoch 33/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0010
# Epoch 34/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0011
# Epoch 35/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 36/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0010
# Epoch 37/100
# 16/16 [==============================] - 1s 52ms/step - loss: 0.0012
# Epoch 38/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0012
# Epoch 39/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.
100
# 16/16 [==============================] - 1s 52ms/step - loss: 9.1108e-04
# Epoch 95/100
# 16/16 [==============================] - 1s 52ms/step - loss: 8.0590e-04
# Epoch 96/100
# 16/16 [==============================] - 1s 52ms/step - loss: 7.4639e-04
# Epoch 97/100
# 16/16 [==============================] - 1s 53ms/step - loss: 7.4894e-04
# Epoch 98/100
# 16/16 [==============================] - 1s 53ms/step - loss: 8.1618e-04
# Epoch 99/100
# 16/16 [==============================] - 1s 52ms/step - loss: 9.0110e-04
# Epoch 100/100
# 16/16 [==============================] - 1s 52ms/step - loss: 7.1765e-04

# %%
predict = modelGRU.predict(X_test)
predict = sc.inverse_transform(predict)
# Out:
# 26/26 [==============================] - 1s 7ms/step

# %%
diff = predict - test

print("MSE:", np.mean(diff**2))
print("MAE:", np.mean(abs(diff)))
print("RMSE:", np.sqrt(np.mean(diff**2)))
# Out:
# MSE: 12448737.60869602
# MAE: 2399.3479832381418
# RMSE: 3528.2768611173387

# %%
plt.figure(figsize=(20,7))
plt.plot(df['Date'].values[2000:], df_volume[2000:], color = 'red', label = 'Real Bitcoin Price')
plt.plot(df['Date'][-predict.shape[0]:].values, predict, color = 'blue', label = 'Predicted Bitcoin Price')
plt.xticks(np.arange(100,df[2000:].shape[0],20))
plt.title('Bitcoin Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.show()

# %%
pred_ = predict[-1].copy()
prediction_full = []
window = 30
df_copy = df.iloc[:, 1:2][1:].values

for j in range(7):
    df_ = np.vstack((df_copy, pred_))
    train_ = df_[:num_shape]
    test_ = df_[num_shape:]
    
    df_volume_ = np.vstack((train_, test_))

    inputs_ = df_volume_[df_volume_.shape[0] - test_.shape[0] - window:]
    inputs_ = inputs_.reshape(-1,1)
    inputs_ = sc.transform(inputs_)

    X_test_2 = []

    for k in range(window, num_2):
        X_test_3 = np.reshape(inputs_[k-window:k, 0], (window, 1))
        X_test_2.append(X_test_3)

    X_test_ = np.stack(X_test_2)
    predict_ = modelGRU.predict(X_test_)
    pred_ = sc.inverse_transform(predict_)
    prediction_full.append(pred_[-1][0])
    df_copy = df_[j:]
# Out:
# 26/26 [==============================] - 0s 8ms/step
# 26/26 [==============================] - 0s 7ms/step
# 26/26 [==============================] - 0s 7ms/step
# 26/26 [==============================] - 0s 7ms/step
# 26/26 [==============================] - 0s 7ms/step
# 26/26 [==============================] - 0s 7ms/step
# 26/26 [==============================] - 0s 7ms/step

# %%
prediction_full_new = np.vstack((predict, np.array(prediction_full).reshape(-1,1)))

df_date = df[['Date']]

for h in range(7):
    kk = pd.to_datetime(df_date['Date'].iloc[-1]) + pd.DateOffset(days=1)
    kk = pd.DataFrame([kk.strftime("%Y-%m-%d")], columns=['Date'])
    df_date = df_date.append(kk)
df_date = df_date.reset_index(drop=True)

# %%
plt.figure(figsize=(20,7))
plt.plot(df['Date'].values[2000:], df_volume[2000:], color = 'red', label = 'Real Bitcoin Price')
plt.plot(df_date['Date'][-prediction_full_new.shape[0]:].values, prediction_full_new, color = 'blue', label = 'Predicted Bitcoin Price')
plt.xticks(np.arange(100,df_date[2000:].shape[0],20))
plt.title('Bitcoin Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.show()
